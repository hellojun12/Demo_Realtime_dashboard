# %%
import os
import pandas as pd
import numpy as np

# %%
train_d = '/Users/junshickyoon/Workspace/Project/Demo_Realtime_dashboard/data/bog_data.csv'
predict_d = '/Users/junshickyoon/Workspace/Project/Demo_Realtime_dashboard/data/train_post_process.csv'

# %%
td = pd.read_csv(train_d)
pdf = pd.read_csv(predict_d)

# %%
df['TIME'] = df['TIME'].str.slice(stop=19)

# %%
len(td)
# Out:
# 105999

# %%
len(pdf)
# Out:
# 105995

# %%
df= pd.merge(left=td, right=pdf, on='TIME', how='left')

# %%
df.iloc[1000:]
# Out:
#                            TIME  ZIH120-02  PIA205B-02A_MIN_x  \
# 1000        2019-01-07 23:10:00          0          18.213499
# 1001        2019-01-07 23:20:00          0          18.210400
# 1002        2019-01-07 23:30:00          0          18.216600
# 1003        2019-01-07 23:40:00          0          18.210400
# 1004        2019-01-07 23:50:00          0          18.213499
# ...                         ...        ...                ...
# 105994  2021-01-06 01:50:00.000          0          17.914400
# 105995  2021-01-06 02:00:00.000          0          17.920500
# 105996  2021-01-06 02:10:00.000          0          17.920500
# 105997  2021-01-06 02:20:00.000          0          17.917500
# 105998  2021-01-06 02:30:00.000          0          17.914400
#
#         PIA205B-02A_MAX_x  PRESSURE-S     FI_SUM     FY_SUM     TI_MEAN  \
# 1000            18.234900       102.2  16.929768  20.792010 -152.197174
# 1001            18.228800       102.2  16.912131  20.789847 -152.181129
# 1002            18.237900       102.2  16.923566  20.705027 -152.191071
# 1003            18.231800       102.2  16.973731  20.917497 -152.187912
# 1004            18.228800       102.2  16.956814  20.862174 -152.204445
# ...                   ...         ...        ...        ...         ...
# 105994          17.935801       102.4  18.024740  24.220691 -152.702347
# 105995          17.938801       102.4  18.008728  24.287336 -152.707321
# 105996          17.938801       102.4  18.037360  24.393723 -152.739403
# 105997          17.941900       102.4  18.020117  24.391902 -152.741676
# 105998          17.938801       102.4  17.998273  24.540736 -152.718216
#
#           LP_TOTAL   FIA_SUM  ...  MAX-MIN_DIFF  TEMPDIFF  MAX_DIFF1  \
# 1000    860.815666  0.009487  ...      0.003000       0.0   0.012199
# 1001    861.004608  0.010607  ...     -0.003000       0.1  -0.006100
# 1002    862.305069  0.009526  ...      0.002899       0.0   0.009100
# 1003    861.756958  0.012422  ...      0.000101      -0.2  -0.006100
# 1004    862.126892  0.010725  ...     -0.006100      -0.1  -0.003000
# ...            ...       ...  ...           ...       ...        ...
# 105994  906.253769  0.007561  ...      0.000101       0.0   0.003101
# 105995  904.574509  0.007921  ...     -0.003099      -0.1   0.003000
# 105996  905.398254  0.008939  ...      0.000000      -0.2   0.000000
# 105997  904.911682  0.010814  ...      0.006100       0.0   0.003099
# 105998  903.337708  0.007973  ...      0.000000       0.0  -0.003099
#
#         MAX_DIFF2  MAX_DIFF3  MIN_DIFF1  MIN_DIFF2  MIN_DIFF3  \
# 1000     0.006100   0.006100   0.009199   0.006100   0.003099
# 1001     0.006100   0.000000  -0.003099   0.006100   0.003000
# 1002     0.003000   0.015200   0.006201   0.003101   0.012300
# 1003     0.003000  -0.003099  -0.006201   0.000000  -0.003099
# 1004    -0.009100   0.000000   0.003099  -0.003101   0.003099
# ...           ...        ...        ...        ...        ...
# 105994   0.009201   0.003101   0.003000   0.009100   0.000000
# 105995   0.006102   0.012201   0.006100   0.009100   0.015200
# 105996   0.003000   0.006102   0.000000   0.006100   0.009100
# 105997   0.003099   0.006100  -0.003000  -0.003000   0.003099
# 105998   0.000000   0.000000  -0.003099  -0.006100  -0.006100
#
#         PIA205B-02A_MIN_y  PIA205B-02A_MAX_y
# 1000            18.214094          18.232578
# 1001            18.230152          18.254278
# 1002            18.225500          18.241490
# 1003            18.233345          18.255890
# 1004            18.218588          18.239120
# ...                   ...                ...
# 105994                NaN                NaN
# 105995                NaN                NaN
# 105996                NaN                NaN
# 105997                NaN                NaN
# 105998                NaN                NaN
#
# [104999 rows x 31 columns]
